# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
v1 = np.array([2,5])
v2 = np.array([3,2])

# %% [markdown]
# Creo una funcion para graficar que recibe como argumentos vectores, los colores y alpha para el valor de transparencia en la grafica

# %% [markdown]
# # **Llamar desde otro Notebook**
# Se guarda ese codigo con el metodo y se escribe:
#
# %run "..\\funciones_auxiliares\graficarVectores.ipynb"

# %%
def graficarVectores(vecs, cols, alpha = 1):
  plt.figure()
  plt.axvline(x = 0, color = "grey", zorder = 0)
  plt.axhline(y = 0, color = "blue", zorder = 0)

  #recorrer el vector con su longitud y los va recorriendo
  #concateno con el origen
  for i in range(len(vecs)):
    x = np.concatenate([[0,0], vecs[i]])
    #grafique, x[0] primera coordenada...  
    plt.quiver([x[0]],
               [x[1]],
               [x[2]],
               [x[3]],
               angles = "xy", scale_units = "xy", scale = 1,
               color = cols[i],
               alpha = alpha)

# %%
graficarVectores([v1, v2] , ["orange", "green"])

# %%
graficarVectores([v1, v2] , ["orange", "green"])
plt.xlim(-1, 8)
plt.ylim(-1, 8)
# Out:
# (-1.0, 8.0)
